# %%
# !pip install textblob
import pandas as pd
import numpy as np
import nltk
#from wordcloud import WordCloud
import matplotlib.pyplot as plt
from textblob import TextBlob
# Out:
# Requirement already satisfied: textblob in c:\users\aditya\anaconda3\envs\tensorflow\lib\site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in c:\users\aditya\anaconda3\envs\tensorflow\lib\site-packages (from textblob) (3.4)
# Requirement already satisfied: six in c:\users\aditya\anaconda3\envs\tensorflow\lib\site-packages (from nltk>=3.1->textblob) (1.12.0)
# Requirement already satisfied: singledispatch in c:\users\aditya\anaconda3\envs\tensorflow\lib\site-packages (from nltk>=3.1->textblob) (3.4.0.3)

# %%
dialogues = pd.read_csv("dialogues_bigbangtheory.csv")

# %%
dialogues.columns
# Out:
# Index(['episode_no', 'dialogue', 'character', 'season_id', 'ep_no',
#        'epidsode_title'],
#       dtype='object')

# %%
l =dialogues[dialogues['character']=='Sheldon']

# %%
for i in l['dialogue']:
    print(i)
    blob = TextBlob(i)
    print(blob.noun_phrases)
# Out:
#  So if a photon is directed through a plane with two slits in it and either slit is observed it will not go through both slits. If it’s unobserved it will, however, if it’s observed after it’s left the plane but before it hits its target, it will not have gone through both slits.
# ['’ s', '’ s', '’ s']
#  There’s no point, I just think it’s a good idea for a tee-shirt.
# ['’ s', '’ s', 'good idea']
#  I think this is the place.
# []
#  Leonard, I don’t think I can do this.
# ['leonard', 'don ’ t']
#  No. We are committing genetic fraud. There’s no guarantee that our sperm is going to generate high IQ offspring, think about that. I have a sister with the same basic DNA mix who hostesses at Fuddruckers.
# ['genetic fraud', '’ s', 'generate high', 'iq', 'dna', 'fuddruckers']
#  I know, and I do yearn for faster downloads, but there’s some poor woman is going to pin her hopes on my sperm, what if she winds up with a toddler who doesn’t know if he should use an integral or a differential to solve the area under a curve.
# ['’ s', 'poor woman', 'doesn ’ t']
#  I wouldn’t.
# ['wouldn ’ t']
#  I want to leave.
# []
#  What’s the protocol for leaving?
# ['’ s']
#  Let’s try just walking out.
# ['’ s']
#  Bye-bye
# ['bye-bye']
#  Are you still mad about the sperm bank?
# ['sperm bank']
#  You want to hear an interesting thing about stairs?
# ['interesting thing']
#  If the height of a single step is off by as little as two millimetres, most people will trip.
# []
#  No, it’s true, I did a series of experiments when I was twelve, my father broke his clavicle.
# ['’ s']
#  No, that was the result of my work with lasers.
# []
#  Evidently.
# ['evidently']
#  Two hundred pound transvestite with a skin condition, yes she is.
# ['skin condition']
#  Hi.
# ['hi']
#  Hi.
# ['hi']
#  Hi.
# ['hi']
#  Great.
# []
#  Bye.
# ['bye']
#  No. We’re going to start Season Two of Battlestar Galactica.
# ['’ re', 'season', 'battlestar galactica']
#  Not with commentary.
# []
#  We never invited Louis-slash-Louise over.
# ['louis-slash-louise']
#  I have a very wide circle. I have 212 friends on myspace.
# ['wide circle']
#  That’s the beauty of it.
# ['’ s']
#  Chat? We don’t chat. At least not offline.
# ['chat', 'don ’ t']
#  To what end?
# []
#  Hi.
# ['hi']
#  Leonard, I’m not expert here but I believe in the context of a luncheon invitation, you might want to skip the reference to bowel movements.
# ['leonard', '’ m', 'luncheon invitation', 'bowel movements']
#  Well, today we tried masturbating for money.
# ['well']
#  Actually that’s my work.
# ['’ s']
#  Yeah, well, it’s just some quantum mechanics, with a little string theory doodling around the edges. That part there, that’s just a joke, it’s a spoof of the Bourne-Oppenheimer approximation.
# ['yeah', '’ s', 'quantum mechanics', 'string theory', '’ s', '’ s', 'bourne-oppenheimer']
#  Yeah.
# ['yeah']
#  If by holy smokes you mean a derivative restatement of the kind of stuff you can find scribbled on the wall of any men’s room at MIT, sure.
# ['derivative restatement', 'men ’ s room', 'mit']
#  Oh, come on. Who hasn’t seen this differential below “here I sit broken hearted?”
# ['oh', 'who', 'hasn ’ t']
#  I didn’t invent them, they’re there.
# ['didn ’ t invent', '’ re']
#  In all of them, that is the point.
# []
#  Um, Penny, that’s where I sit.
# ['um', 'penny', '’ s']
#  No, I sit there.
# []
#  What’s the difference?
# ['’ s']
#  In the winter that seat is close enough to the radiator to remain warm, and yet not so close as to cause perspiration. In the summer it’s directly in the path of a cross breeze created by open windows there, and there. It faces the television at an angle that is neither direct, thus discouraging conversation, nor so far wide to create a parallax distortion, I could go on, but I think I’ve made my point.
# ['’ s', 'cross breeze', 'open windows', 'parallax distortion', '’ ve']
#  Well.
# ['well']
#  Fine. (Wanders in circles, looking lost.)
# ['wanders']
#  Aaah!
# ['aaah']
#  That’s not true. Koothrapali and Wolowitz come over all the time.
# ['’ s', 'koothrapali', 'wolowitz']
#  Tuesday night we played Klingon boggle until one in the morning.
# ['klingon']
#  I resent you saying we don’t have company.
# ['don ’ t']
#  That is an antisocial implication.
# ['antisocial implication']
#  Yes, it tells us that you participate in the mass cultural delusion that the Sun’s apparent position relative to arbitrarily defined constellations and the time of your birth somehow effects your personality.
# ['cultural delusion', 'sun', '’ s', 'apparent position']
#  That’s interesting. Leonard can’t process corn.
# ['’ s', 'leonard', '’ t process corn']
#  You’re lactose intolerant.
# ['’ re lactose intolerant']
#  It took you four years to get through High School?
# ['high school']
#  You? No, you’ll only make it worse.
# ['’ ll']
#  Yes.
# []
#  Yes.
# []
#  No?
# []
#  No.
# []
#  Well this is an interesting development.
# ['well', 'interesting development']
#  It has been some time since we’ve had a woman take her clothes off in our apartment.
# ['’ ve']
#  Point taken. It has been some time since we’ve had a woman take her clothes off after which we didn’t want to rip our eyes out.
# ['’ ve', 'didn ’ t']
#  So, what exactly are you trying to accomplish here?
# []
#  That woman in there’s not going to have sex with you.
# ['’ s']
#  Oh, good. Then you won’t be disappointed.
# ['oh', '’ t']
#  Yes, but not of the same species.
# []
#  Oh, of course.
# ['oh']
#  Do you think this possibility will be helped or hindered when she discovers your Luke Skywalker no-more-tears shampoo?
# ['luke skywalker', 'no-more-tears shampoo']
#  Leonard has a lady over.
# ['leonard']
#  Technically that would be coitus interruptus.
# ['technically', 'coitus interruptus']
#  I really think we should examine the chain of causality here.
# []
#  Event A. A beautiful woman stands naked in our shower. Event B. We drive half way across town to retrieve a television set from the aforementioned woman’s ex-boyfriend. Query, on what plane of existence is there even a semi-rational link between these events?
# ['event', 'beautiful woman stands', 'event', 'aforementioned woman ’ s ex-boyfriend', 'query', 'semi-rational link']
#  Ah, yes, well that may be the proximal cause of our journey, but we both know it only exists in contradistinction to the higher level distal cause.
# ['level distal']
#  You think with your penis.
# []
#  Oh, right, yes, I could have stayed behind and watched Wolowitz try to hit on Penny in Russian, Arabic and Farsi. Why can’t she get her own TV.
# ['oh', 'wolowitz', 'penny', 'russian', 'arabic', 'farsi', '’ t', 'own tv']
#  No I don’t. And neither do you.
# ['don ’ t']
#  You did not break up with Joyce Kim, she defected to North Korea.
# ['joyce kim', 'korea']
#  So we get to have a scene with him?
# []
#  Leonard, the two of us can’t even carry a TV.
# ['leonard', '’ t']
#  Hello.
# ['hello']
#  Okay, thanks for your time.
# ['okay']
#  Leonard, the TV is in the building, we’ve been denied access to the building, ergo we are done.
# ['leonard', '’ ve']
#  My apologies. What’s your plan.
# ['’ s']
#  It’s just a privilege to watch your mind at work.
# ['’ s']
#  What do you think their combined IQ is?
# ['iq']
#  Good thinking, I’ll just be the muscle.
# ['’ ll']
#  From the intercom.
# []
#  Tell him about our IQ.
# ['iq']
#  Leonard.
# ['leonard']
#  My mom bought me those pants.
# []
#  You’re going to have to call her.
# ['’ re']
#  It’s okay. It wasn’t my first pantsing, and it won’t be my last.
# ['’ s okay', 'wasn ’ t', '’ t']
#  Well you got me out of my pants.
# ['well']
#  Don’t think like that, you’re not going to die alone.
# ['don', '’ t', '’ re']
#  And you’re certainly not going to win a Nobel Prize.
# ['’ re', 'nobel']
#  That was a valid hypothesis? What is happening to you?
# ['valid hypothesis']
#  Thank you. You’re not done with her, are you?
# ['thank', '’ re']
#  Not to mention imaginary.
# []
#  We can’t have Thai food, we had Indian for lunch.
# ['’ t', 'thai']
#  They’re both curry based cuisines.
# ['’ re']
#  They would be gastronomically redundant. I can see we’re going to have to spell out everything for this girl.
# ['’ re']
#  I don’t know what your odds are in the world as a whole, but as far as the population of this car goes, you’re a veritable Mack Daddy.
# ['don ’ t', '’ re', 'mack daddy']
#  Since it’s not bee season, you can have my epinephrine.
# ['’ s', 'bee season']
#  You don’t need chopsticks, this is Thai food.
# ['don ’ t need chopsticks', 'thai']
#  Thailand has had the fork since the latter half of the nineteenth century. Interestingly they don’t actually put the fork in their mouth, they use it to put the food on a spoon which then goes into their mouth.
# ['thailand', 'interestingly', 'don ’ t']
#  Hi.
# ['hi']
#  Don’t take it personally, it’s his pathology, he can’t talk to women.
# ['don', '’ t', '’ s', '’ t talk']
#  You’re kidding, right?
# ['’ re']
#  You realise that scene was rife with scientific inaccuracy.
# ['scientific inaccuracy']
#  Oh no, let’s assume that they can. Lois Lane is falling, accelerating at an initial rate of 32 feet per second per second. Superman swoops down to save her by reaching out two arms of steel. Miss Lane, who is now travelling at approximately 120 miles per hour, hits them, and is immediately sliced into three equal pieces.
# ['oh', '’ s', 'lois lane', 'initial rate', 'superman', 'miss lane', 'equal pieces']
#  In what space, sir, in what space? She’s two feet above the ground. Frankly, if he really loved her, he’d let her hit the pavement. It would be a more merciful death.
# ['’ s', 'frankly', '’ d', 'merciful death']
#  Are you listening to yourself, it is well established that Superman’s flight is a feat of strength, it is an extension of his ability to leap tall buildings, an ability he derives from Earth’s yellow Sun.
# ['superman', '’ s flight', 'tall buildings', 'earth', '’ s', 'sun']
#  Uh, a combination of the moon’s solar reflection and the energy storage capacity of Kryptonian skin cells.
# ['uh', 'moon ’ s solar reflection', 'energy storage capacity', 'kryptonian', 'skin cells']
#  Challenge accepted. (Tries door.) We’re locked out.
# ['challenge', 'tries', '’ re']
#  I hardly think so.
# []
#  Well, we don’t have a dolly, or lifting belts, or any measurable upper body strength.
# ['well', 'don ’ t', 'measurable upper body strength']
#  Archimedes would be so proud.
# ['archimedes']
#  Yes, but they all involve a green lantern and a power ring.
# ['green lantern', 'power ring']
#  Exactly half.
# ['exactly']
#  What’s your formula for the corner.
# ['’ s']
#  Ah, gravity, thou art a heartless bitch.
# ['thou art', 'heartless bitch']
#  You do understand that our efforts here will in no way increase the odds of you having sexual congress with this woman?
# ['way increase', 'sexual congress']
#  Yeah, those are men who just had sex.
# ['yeah']
#  No we’re not, no we’re not, no we’re not.
# ['’ re', '’ re', '’ re']
#  Watch your fingers. Watch your fingers. Oh God, my fingers!
# ['watch', 'watch', 'oh god']
#  No, it hurt… (looking around) Great Caesar’s Ghost, look at this place?
# ['caesar', '’ s', 'ghost']
#  A little messy? The Mandelbrot set of complex numbers is a little messy, this is chaos. Excuse me, explain to me an organisational system where a tray of flatware on a couch is valid. I’m just inferring that this is a couch, because the evidence suggests the coffee table’s having a tiny garage sale.
# ['mandelbrot', 'complex numbers', 'excuse', 'organisational system', '’ m', 'evidence suggests', 'coffee table ’ s', 'tiny garage sale']
#  No.
# []
#  Excuse me, but I think we’ve both found that helpful at times.
# ['excuse', '’ ve']
#  Hang on.
# ['hang']
#  Straightening up.
# ['straightening']
#  This is not anyone’s home, this is a swirling vortex of entropy.
# ['’ s home']
#  Because it was immaculate, I mean, you open that man’s closet, it was left to right, evening gowns, cocktail dresses, then his police uniforms.
# ['man ’ s closet', 'evening gowns', 'cocktail dresses', 'police uniforms']
#  I helped run some cable for a webcam.
# []
#  (sucks in breath)
# []
#  No?
# []
#  No.
# []
#  Penny, I just want you to know that, you don’t have to live like this. I’m here for you.
# ['penny', 'don ’ t', '’ m']
#  Sssshhhh! Penny’s sleeping.
# ['sssshhhh', 'penny', '’ s']
#  I had no choice. I couldn’t sleep knowing that just outside my bedroom was our living room, and just outside our living room was that hallway, and immediately adjacent to that hallway was… this.
# ['couldn ’ t sleep', 'hallway was…']
#  I just gave you a reasonable explanation.
# ['reasonable explanation']
#  Don’t be ridiculous. I have no peers.
# ['don', '’ t']
#  You might want to speak in a lower register.
# []
#  Evolution has made women sensitive to high pitched noises while they sleep, so that they’ll be roused by a crying baby. If you want to avoid waking her, speak in a lower register.
# ['evolution', '’ ll']
#  No, (lowering his voice dramatically,) that’s ridiculous.
# ['’ s']
#  I am not leaving until I’m done.
# ['’ m']
#  If you have time to lean, you have time to clean.
# []
#  Morning.
# ['morning']
#  I have to say, I slept splendidly. Granted, not long, but just deeply and well.
# ['granted']
#  Sarcasm?
# ['sarcasm']
#  Granted, my methods may have been somewhat unorthodox, but I think the end result will be a measurable enhancement of Penny’s quality of life.
# ['granted', 'end result', 'measurable enhancement', 'penny', '’ s quality']
#  You don’t think that crosses a line?
# ['don ’ t']
#  You have a sarcasm sign?
# []
#  Do you want some cereal. I’m feeling so good today I’m going to choose from the low fibre end of the shelf. Hello, Honey Puffs.
# ['’ m feeling', '’ m', 'low fibre end', 'hello', 'honey puffs']
#  I may have left a suggested organisational schematic for her bedroom closet.
# ['organisational schematic', 'bedroom closet']
#  Goodbye, Honey Puffs, hello Big Bran.
# ['honey puffs', 'bran']
#  Really more to organise, you’re not actually dirty, per se.
# ['really', '’ re']
#  And snoring. And that’s probably just a sinus infection, but it could be sleep apnoea, you might want to see an otolaryngologist. It’s a throat doctor.
# ['’ s', 'sinus infection', 'sleep apnoea', '’ s', 'throat doctor']
#  Depending on the depth, that’s either a proctologist or a general surgeon. (Leonard holds up a sign reading “Sarcasm”) Oh!
# ['depending', '’ s', 'general surgeon', 'leonard', 'reading “', 'sarcasm', 'oh']
#  Penny, Penny, just to clarify because there will be a discussion when you leave, is your objection solely to our presence in the apartment while you were sleeping, or do you also object to the imposition of a new organisational paradigm. (Penny stares in disbelief, then leaves.) Well that was a little non-responsive.
# ['penny', 'penny', 'new organisational paradigm', 'penny', 'well']
#  That wasn’t sarcasm?
# ['wasn ’ t sarcasm']
#  Wooh, boy, you are all over the place this morning. (Knocks on Penny’s door.) I have a masters and two PhD’s, I should not have to do this.
# ['wooh', 'knocks', 'penny', '’ s door', 'phd', '’ s']
#  I am truly sorry for what happened last night, I take full responsibility. And I hope that it won’t colour your opinion of Leonard, who is not only a wonderful guy, but also, I hear, a gentle and thorough lover. (Penny closes door in his face.) I did what I could.
# ['full responsibility', '’ t colour', 'leonard', 'wonderful guy', 'thorough lover', 'penny', 'closes door']
#  His imaginary girlfriend broke up with him.
# ['imaginary girlfriend']
#  Check.
# []
#  Check.
# []
#  Considering what? How great this place looks?
# []
#  We could put her stereo back there.
# []
#  Run an infra-red repeater, photocell here, emitter here, easy peasy.
# ['run', 'easy peasy']
#  Hang on Penny. How about fans, here and here?
# ['hang', 'penny']
#  And if water is involved we’re going to have to ground the crap out of the thing.
# ['’ re']
#  Right, then the entire thing’s one big heat sink.
# ['right', 'entire thing ’ s', 'big heat']
#  Good lord!
# ['good lord']
#  Lock and load.
# ['lock']
#  I’ve got the Sword of Azeroth!
# ['’ ve', 'sword', 'azeroth']
#  There is no more Sheldon, I am the Swordmaster!
# ['sheldon', 'swordmaster']
#  Goodbye, peasants.
# []
#  I’m a rogue knight elf, don’t you people read character descriptions? Wait, wait, wait, somebody just clicked “buy it now.”
# ['’ m', 'rogue knight elf', 'don ’ t', 'character descriptions', 'wait']
#  Wooh, I’m all sweaty, anybody want to log on to second life and go swimming, I just built a virtual pool.
# ['wooh', '’ m', 'virtual pool']
#  Don’t forget the mail you took accidentally on purpose so you’d have an excuse to talk to her.
# ['don', '’ t', '’ d']
#  Penny for your thoughts.
# ['penny']
#  Please don’t tell me that your hopeless infatuation is devolving into pointless jealousy.
# ['please', 'don ’ t', 'hopeless infatuation', 'pointless jealousy']
#  Well, at least now you can retrieve the black box from the twisted smouldering wreckage that was once your fantasy of dating her, and analyse the data so that you don’t crash into geek mountain again.
# ['well', 'black box', 'don ’ t crash', 'geek mountain']
#  The dietician at the cafeteria with the limp and the lazy eye?
# ['lazy eye']
#  Well, I don’t think you have a shot there. I have noticed that Lesley Winkle recently started shaving her legs. Now, given that winter is coming one can only assume that she is signalling sexual availability.
# ['well', 'don ’ t', 'lesley winkle', 'sexual availability']
#  That depends. When I learn that I’m a robot, will I be able to handle it?
# ['’ m']
#  Uh, let me ask you this. When I learn that I’m a robot, would I be bound by Asimov’s three laws of robotics?
# ['uh', '’ m', 'asimov', '’ s']
#  Of course not.
# []
#  Well, no.
# ['well']
#  The internet’s been down for half an hour.
# ['internet ’ s']
#  Oh, I’ve seen that look before. This is just going to be two weeks of moping and tedious emo songs, and calling me to come down to pet stores to look at cats. I don’t know if I can take it.
# ['oh', '’ ve', 'tedious emo songs', 'pet stores', 'don ’ t']
#  Oh, good lord.
# ['oh', 'good lord']
#  If you’re compiling a mix CD for a double suicide. (Leonard is taking supplies out of a bag) Oh, I hope that scratching post is for you.
# ['’ re', 'mix cd', 'double suicide', 'leonard', 'oh']
#  Leonard, listen to me…
# ['leonard']
#  Leonard, do you really think you can satisfy your need for a relationship with a genetically altered cat?
# ['leonard']
#  Oh, come on, Leonard! This is obviously about Penny.
# ['oh', 'leonard', 'penny']
#  Okay, look, I think that you have as much of a chance of having a sexual relationship with Penny as the Hubble Telescope does of discovering at the centre of every black hole is a little man with a flashlight searching for a circuit breaker. Nevertheless, I do feel obligated to point out to you that she did no reject you. You did not ask her out.
# ['okay', 'sexual relationship', 'penny', 'hubble telescope', 'black hole', 'circuit breaker']
#  No. No, now that was not my point. My point was, don’t buy a cat.
# ['don ’ t']
#  Oh, goody, we’re getting a cat.
# ['oh', '’ re']
#  Could you be more specific?
# []
#  No. The dark crescent-shaped patterns under your arms conceal it nicely. What time is your date?
# ['arms conceal']
#  Perfect, that gives you two hours and fifteen minutes for that dense molecular cloud of Aramis to dissipate.
# ['perfect', 'dense molecular cloud', 'aramis']
#  Not if you’re a rugby team.
# ['’ re', 'rugby team']
#  Why would I join you?
# []
#  Oh, no, no, no, well now, there’s always the possibility that alcohol and poor judgement on her part might lead to a nice romantic evening.
# ['oh', '’ s', 'poor judgement', 'nice romantic evening']
#  Of course, there’s the other possibility that this date kicks off a rather unpleasant six months of the two of you passing awkwardly in the hall until one of you breaks down and moves to another zip code.
# ['’ s', 'zip code']
#  If I could of, I would of.
# []
#  Is the sex starting now?
# []
#  Oh, okay, well then, calm down.
# ['oh']
#  Alright, alright, well, just, sit down, yes, sit down, now close your eyes.
# ['alright']
#  Just do it.
# []
#  Now try to increase your alpha-wave activity.
# ['alpha-wave activity']
#  It’s a bio-feedback technique, it’s relaxation through brain-wave manipulation, I read a paper about it in the Journal of American Neuroscience, it was a little sparsely sourced but I think the basic science is valid, I probably have it here somewhere.
# ['’ s', 'bio-feedback technique', '’ s relaxation', 'brain-wave manipulation', 'neuroscience', 'basic science']
#  Me?
# []
#  What should I tell her.
# []
#  Okay.
# ['okay']
#  Got it. So I’m assuming nothing venereal. I’ll just tell her that you had a routine colonoscopy and haven’t quite bounced back.
# ['got', '’ m', '’ ll', 'routine colonoscopy', 'haven ’ t']
#  But I thought you wanted to cancel?
# []
#  Why would she be expecting me?
# []
#  So, how was your date?
# []
#  Score one for liquor and poor judgement.
# ['score', 'poor judgement']
#  I’ve been thinking about time travel again.
# ['’ ve', 'time travel']
#  Put it on the back burner. Anyway, it occurs to me, if I ever did perfect a time machine, I’d just go into the past and give it to myself, thus eliminating the need for me to invent it in the first place.
# ['back burner', 'anyway', 'time machine', '’ d']
#  Yeah, it really takes the pressure off.
# ['yeah']
#  It’s time travel, Leonard, I will have already done that.
# ['’ s time travel', 'leonard']
#  No, congratulations will have been in order. You know, I’m not going to enjoy this party.
# ['’ m']
#  At the last department party, Dr Finkleday cornered me and talked about spelunking for 45 minutes.
# ['department party', 'dr finkleday']
#  You know what’s interesting about caves, Leonard?
# ['’ s', 'leonard']
#  Nothing.
# []
#  How’s this? Pleased to meet you, Dr Gablehouser. How fortunate for you that the University has chosen to hire you, despite the fact that you’ve done no original research in 25 years, and instead have written a series of popular books that reduce the great concepts of science to a series of anecdotes, each one dumbed down to accommodate the duration of an average bowel movement. Mahalo.
# ['’ s', 'pleased', 'dr gablehouser', '’ ve', 'original research', 'popular books', 'great concepts', 'average bowel movement', 'mahalo']
#  Do you know there are only eight consonants in the Hawaiian language.
# ['hawaiian language']
#  Well here’s an interesting turn of events.
# ['well', '’ s', 'interesting turn']
#  A more plausible explanation is that his work in robotics has made an amazing leap forward.
# ['plausible explanation', 'amazing leap']
#  An actual real scientist. (To Leonard) How was that?
# ['actual real scientist', 'leonard']
#  I can’t believe he fired me.
# ['’ t']
#  In my defence, I prefaced that by saying “with all due respect.”
# ['due respect']
#  Morning.
# ['morning']
#  This isn’t breakfast, it’s an experiment.
# ['isn ’ t breakfast', '’ s']
#  I finally have the time to test my hypothesis, about the separation of the water molecules from the egg proteins, and its impact vis-a-vis taste.
# ['water molecules', 'egg proteins', 'impact vis-a-vis taste']
#  As do I.
# []
#  I don’t want my job back. I’ve spent the last three and a half years staring at greaseboards full of equations. Before that I spent four years working on my thesis. Before that I was in college, and before that, I was in the fifth grade. This is my first day off in decades, and I’m going to savour it.
# ['don ’ t', '’ ve', '’ m']
#  I’m not just fixing my eggs, I’m fixing everyone’s eggs.
# ['’ m', '’ m', '’ s eggs']
#  Use new eggs. (There is a knock on the door).
# ['new eggs']
#  Oh, well this would be one of those circumstances that people unfamiliar with the law of large numbers would call a coincidence.
# ['oh', 'large numbers']
#  I need eggs. Four dozen should suffice.
# []
#  Yes, and evenly distributed amongst brown, white, free range, large, extra-large and jumbo.
# ['free range']
#  Never mind, you won’t get it right, I’d better come with you.
# ['never', '’ t', '’ d']
#  I’m taking a sabbatical, because I won’t kow-tow to mediocre minds.
# ['’ m', '’ t kow-tow', 'mediocre minds']
#  Theoretical physicists do not get canned. But yeah.
# ['theoretical']
#  No it doesn’t. Not unless the two doors are connected by relays, or there are motion sensors involved.
# ['doesn ’ t', 'motion sensors']
#  Or the first door closing causes a change of air pressure that acts upon the second door.
# ['air pressure']
#  Slow down. Slow down, please slow down.
# []
#  Look, you’re not leaving yourself enough space between cars.
# ['’ re']
#  No, no. Let me do the math for you, this car weighs let’s say 4,000lb, now add say 140 for me, 120 for you.
# ['’ s']
#  Oh, I’m sorry, did I insult you? Is your body mass somehow tied into your self worth?
# ['oh', '’ m', 'body mass']
#  Interesting. Anyway, that gives us a total weight of, let’s say, 4,400lb.
# ['interesting', 'anyway', 'total weight', '’ s']
#  Fine. We’re travelling forward at, good Lord, 51 miles an hour. Now let’s assume that your brakes are new and the callipers are aligned, still, by the time we come to a stop, we’ll be occupying the same space as that Buick in front of us, an impossibility that nature will quickly resolve into death, mutilation and… oh look, they built a new put-put course.
# ['’ re', 'good lord', '’ s', '’ ll', 'buick', 'mutilation and… oh look', 'new put-put course']
#  This is great. Look at me, out in the real world of ordinary people, just living their ordinary, colourless, workaday lives.
# ['real world', 'ordinary people']
#  No, thank you. And thank you, ordinary person. Hey, you want to hear an interesting thing about tomatoes.
# ['ordinary person', 'hey', 'interesting thing']
#  Uh, yes, but anyone who knows anything about the dynamics of bacterial growth knows to pick up their refrigerated foods on the way out of the supermarket.
# ['uh', 'bacterial growth']
#  No, this is fun. Oh, the thing about tomatoes, and I think you’ll really enjoy this, is, they’re shelved with the vegetables, but they’re technically a fruit.
# ['oh', '’ ll', '’ re', '’ re']
#  Isn’t it?
# ['isn', '’ t']
#  Well, there’s some value to taking a multivitamin, but the human body can only absorb so much, what you’re buying here are the ingredients for very expensive urine.
# ['well', '’ s', 'human body', '’ re buying', 'expensive urine']
#  Well then you’ll want some manganese.
# ['well', '’ ll']
#  That was fun. Maybe tomorrow we can go to one of those big warehouse stores.
# ['big warehouse stores']
#  Are you sure. There are a lot of advantages to buying in bulk. For example, I noticed that you purchase your tampons one month’s supply at a time.
# ['month ’ s']
#  Well think about it, it’s a product that doesn’t spoil, and you’re going to be needing them for at least the next thirty years.
# ['well', '’ s', 'doesn ’ t spoil', '’ re']
#  Well, thirty, thirty five, hey, when did your mother go into menopause?
# ['well']
#  Oh, Penny, this is a natural human process, and we’re talking about statistically significant savings. Now, if you assume 15 tampons per cycle and a 28 day cycle, are you fairly regular? (Penny shuts door in his face.) Okay, no warehouse store, but we’re still on for put-put golf, right?
# ['oh', 'penny', 'natural human process', '’ re', 'significant savings', 'day cycle', 'penny', 'shuts door', 'okay', 'warehouse store', '’ re', 'put-put golf']
#  I think it’s her time of the month. I marked the calendar for future reference.
# ['’ s', 'future reference']
#  It’s an experiment.
# ['’ s']
#  Oh, that was a dead end. Scrambled eggs are as good as they’re ever going to be.
# ['oh', 'dead end', 'scrambled', '’ re']
#  I read an article about Japanese scientists, who inserted DNA from luminous jellyfish into other animals, and I thought hey, fish nightlights.
# ['japanese scientists', 'dna', 'luminous jellyfish', 'fish nightlights']
#  It’s a billion dollar idea. Shhhhh!
# ['’ s', 'dollar idea', 'shhhhh']
#  Oh, no, no, no. No, I’ve too much to do.
# ['oh', '’ ve']
#  Shhhhh!
# ['shhhhh']
#  That’s just the beginning. I also have an idea for a bulk mail-order feminine hygiene company. Oh, glow in the dark tampons! Leonard, we’re going to be rich.
# ['’ s', 'bulk mail-order', 'feminine hygiene company', 'oh', 'dark tampons', 'leonard', '’ re']
#  Thank you.
# ['thank']
#  I was working with luminous fish, and I thought, hey, loom! Mom, what are you doing here?
# ['luminous fish']
#  I know, but why?
# []
#  This is not a sarape. This is a poncho. A sarape is open at the sides, a poncho is closed, this is a poncho, and neither is a reason to call someone’s mother.
# ['’ s mother']
#  I went to the market with Penny.
# ['penny']
#  Well then buckle up, in the next four to eight days she’s going to get very crabby.
# ['well', '’ s']
#  Yes, well I’m not a child, I’m a grown man capable of living my life as I see fit. And I certainly don’t need someone telling on me to my mother.
# ['’ m', '’ m', 'don ’ t need']
#  To my room, and no-one’s allowed in.
# ['no-one ’ s']
#  Morning.
# ['morning']
#  It’s my idea of what DNA would look like in a silicon based life form.
# ['’ s', 'dna', 'life form']
#  What do you want, mom?
# []
#  Yeah.
# ['yeah']
#  What for?
# []
#  No.
# []
#  I’m not going to apologise, I didn’t say anything that wasn’t true.
# ['’ m', 'didn ’ t', 'wasn ’ t']
#  Why not?
# []
#  Wouldn’t have been any ass-kickings if that stupid death ray had worked.
# ['wouldn', '’ t', 'stupid death ray']
#  Dr Gablehouser.
# ['dr gablehouser']
#  Um, as you know, several weeks ago in our first encounter we may have gotten off on the wrong foot, when I called you an idiot. And I just wanted to say that I was wrong. To point it out.
# ['um', 'wrong foot']
#  I got my job back.
# []
#  I’m not quite sure. It involves a part of the human experience that has always eluded me.
# ['’ m', 'human experience']
#  Thanks, mom. Mom?
# ['thanks']
#  Is Dr Gablehouser going to be my new daddy?
# ['dr gablehouser', 'new daddy']
#  Alright, I’m moving my infantry division, augmented by a battalion of Orcs from Lord of the Rings, we flank the Tennessee Volunteers, and the North once again wins the Battle of Gettysburg.
# ['alright', '’ m', 'infantry division', 'orcs', 'rings', 'tennessee volunteers', 'gettysburg']
#  We don’t eat here, I don’t know what’s good.
# ['don ’ t', 'don ’ t', '’ s']
#  Statistically unlikely.
# ['statistically']
#  I like the hamburgers where we usually have hamburgers, you can’t make the assumption that I’ll like the hamburgers here.
# ['’ t', '’ ll']
#  Can’t we just go to Big Boy? They only have one burger. The Big Boy.
# ['’ t']
#  Excuse me, in a world that already includes the Big Boy, why would I settle for something like a Big Boy?
# ['excuse']
#  Fine, I’ll have the Barbecue Burger.
# ['’ ll', 'barbecue burger']
#  Waitresses don’t yell at you at Big Boy.
# ['waitresses', 'don ’ t yell']
#  We don’t. This is a disturbing aberration.
# ['don ’ t', 'disturbing aberration']
#  He asked her out once, it was an embarrassing failure.
# []
#  Oh, I’m sorry, was that supposed to be a secret?
# ['oh', '’ m']
#  Well I assume she meant that the two of you together would constitute a couple that others might consider cute. An alternate, and somewhat less likely interpretation, is that you could manufacture one. As in, oh look, Leonard and Lesley made Mr and Mrs Goldfarb, aren’t they adorable.
# ['well', 'likely interpretation', 'oh look', 'leonard', 'lesley', 'mr', 'goldfarb', 'aren ’ t']
#  You’re a lucky man, Leonard.
# ['’ re', 'lucky man', 'leonard']
#  You’re talking to one of the three men in the Western hemisphere capable of following that train of thought.
# ['’ re', 'western hemisphere']
#  I said I could follow it, I didn’t say I cared.
# ['didn ’ t']
#  I need your opinion on a matter of semiotics.
# []
#  Semiotics. The study of signs and symbols, it’s a branch of philosophy related to linguistics.
# ['semiotics', '’ s']
#  Just come with me.
# []
#  Well?
# ['well']
#  What does it mean?
# []
#  Yes, but I was eleven.
# []
#  So you’re saying Leonard has a girl in there.
# ['’ re', 'leonard']
#  Oh, yes, but there’s usually planning, courtship and advance notice. Last time I was able to book a cruise to the Arctic to see a solar eclipse.
# ['oh', '’ s', 'arctic', 'solar eclipse']
#  I didn’t have to, the dates just happened to coincide.
# ['didn ’ t']
#  Well, there’s Leonard. (Picking up violin case) And he’s either with Lesley Winkle or a 1930’s gangster.
# ['well', '’ s', 'leonard', 'picking', 'violin case', '’ s', 'lesley winkle', '’ s gangster']
#  No, no, wait, hold on.
# []
#  I don’t know what the protocol is here. Do I stay, do I leave? Do I wait to greet them with a refreshing beverage?
# ['don ’ t']
#  Hi, Leonard. It’s me, Sheldon. In the living room. I just, I wanted you to know I saw the tie. Message received. You’re welcome. You carry on. Give my best to Lesley.
# ['hi', 'leonard', '’ s', 'sheldon', 'message', '’ re', 'lesley']
#  Big boy! (Wakes up, looks at watch, wraps self in blanket, walks towards kitchen) Someone touched my board. Oh God, my board. Leonard! Leonard!
# ['big boy', 'wakes', 'wraps self', 'someone', 'oh god', 'leonard', 'leonard']
#  My equations, someone’s tampered with my equations.
# ['’ s']
#  Of course I’m sure. Look at the beta-function of quantum chrono-dynamics, the sign’s been changed.
# ['’ m', 'quantum chrono-dynamics', '’ s']
#  Are you insane? Are you out of your mind? Are you…. hey look, that fixes the problem I’ve been having.
# ['hey look', '’ ve']
#  You did this?
# []
#  Cool?
# ['cool']
#  Uh-duh, hold on, hold on!
# ['uh-duh']
#  Who told you you could touch my board?
# ['who']
#  I don’t come into your house and touch your board.
# ['don ’ t']
#  Oh, that is so… so…
# ['oh', 'so… so…']
#  Inconsiderate, that is the adjective, inconsiderate.
# ['inconsiderate']
#  I’m coming.
# ['’ m']
#  Boy, you’re wound awfully tight for a man who just had sexual intercourse.
# ['’ re', 'sexual intercourse']
#  Do you realise I may have to share a Nobel Prize with your booty call?
# ['nobel']
#  She’s not that intelligent.
# ['’ s']
#  She got lucky.
# []
#  I don’t have to believe in it for her to be lucky.
# ['don ’ t']
#  Leonard?
# ['leonard']
#  I still don’t care.
# ['don ’ t care']
#  You know, I think I may have misjudged this restaurant.
# []
#  I won’t go out on a limb, but I think we may be looking at my new Tuesday hamburger.
# ['’ t']
#  Way ahead of you. I was thinking of moving Big Boy to Thursdays, and just dropping Soup Plantation.
# ['thursdays', 'soup plantation']
#  Yeah, the name always confused me anyway, Soup Plantation. You can’t grow soup.
# ['yeah', 'soup plantation', '’ t']
#  Terrific, you’ll be happy to know that I plan to come here every Tuesday night for the foreseeable future.
# ['terrific', '’ ll', 'foreseeable future']
#  Who do I speak to about permanently reserving this table?
# ['who']
#  You know why this hamburger surpasses the Big Boy? This is a single decker hamburger whereas the Big Boy is a double decker. This has a much more satisfying meat to bun to condiment ratio.
# ['hamburger surpasses', 'decker hamburger whereas', 'double decker', 'satisfying meat', 'condiment ratio']
#  Of course I’m listening. Blah blah, hopeless Penny delusion, blah blah blah.
# ['’ m', 'blah', 'penny', 'blah blah blah']
#  You know, we were annihilated by our own incompetence and the inability of some people to follow the chain of command.
# ['own incompetence']
#  No, I want to talk about the fact that Wolowitz shot me in the back.
# ['wolowitz']
#  I was giving clear, concise orders.
# ['concise orders']
#  Sure, if you consider being fragged by your own troops fun. (To Howard) You clear space on your calendar, there will be an enquiry.
# ['sure', 'own troops fun', 'howard', 'clear space']
#  Dancing?
# ['dancing']
#  The thing is, we’re not….
# ['’ re not…']
#  No.
# []
#  A Halloween party?
# ['halloween']
#  Yes, but are the costumes random, or genre specific?
# ['costumes random']
#  What about comic-books?
# []
#  Anime?
# ['anime']
#  TV , film, D&D, Manga, Greek Gods, Roman Gods, Norse Gods…
# ['manga', 'norse gods…']
#  Oh no! (He is also wearing a Flash costume.)
# ['oh', 'flash']
#  See, this is why I wanted to have a costume meeting.
# ['costume meeting']
#  I don’t care if anybody gets it, I’m going as the Doppler Effect.
# ['don ’ t care', '’ m', 'doppler effect']
#  If I have to, I can demonstrate. Neeeeoooowwwww!
# ['neeeeoooowwwww']
#  Well, what exactly do you mean by embarrass you?
# ['well']
#  Well, there’s nothing embarrassing about that, your father worked with Lewis Leakey, a great anthropologist. It had nothing to do with your bed-wetting.
# ['well', '’ s', 'lewis leakey', 'great anthropologist']
#  And you said the party starts at seven.
# []
#  It’s 7
# ['’ s']
#  So what time does the costume parade start?
# ['costume parade']
#  Yeah, so the judges can give out the prizes for best costume, you know, most frightening, most authentic, most accurate visual representation of a scientific principle.
# ['yeah', 'accurate visual representation', 'scientific principle']
#  This party is just going to suck.
# []
#  Yes. It’s the apparent change in the frequency of a wave caused by relative motion between the source of the wave and the observer.
# ['’ s', 'relative motion']
#  See, people get it.
# []
#  I’m confused. If there’s no costume parade, what are we doing here?
# ['’ m', '’ s', 'costume parade']
#  Telepathically?
# ['telepathically']
#  And that’s the kind of sloppy costuming which results from a lack of rules and competition.
# ['’ s']
#  Well, I actually might be able to help.
# ['well']
#  Like Jane Goodall observing the apes, I initially saw their interactions as confusing and unstructured, but patterns emerge, they have their own language if you will.
# ['jane goodall', 'own language']
#  Well, it seems that the newcomer approaches the existing group with the greeting “How wasted am I?” which is met with an approving chorus of “Dude.”
# ['well', 'newcomer approaches', 'greeting “', 'dude']
#  That’s as far as I’ve gotten.
# ['’ s', '’ ve']
#  Good luck.
# ['good luck']
#  Oh, I hardly think so.
# ['oh']
#  Aren’t you afraid I’ll embarrass you?
# ['aren', '’ t', '’ ll embarrass']
#  Alright, but if we’re going to use flight metaphors I’m much more suited to being the guy from the FAA, analysing wreckage.
# ['alright', '’ re', 'flight metaphors', '’ m', 'faa']
#  Hello.
# ['hello']
#  Me? I’ll give you a hint. Neeeeooooowwwww!
# ['’ ll', 'neeeeooooowwwww']
#  Close! Neeeeeoooooowwwww!
# ['close', 'neeeeeoooooowwwww']
#  Neeeeeooooowwwwww!
# ['neeeeeooooowwwwww']
#  I’m the Doppler Effect.
# ['’ m', 'doppler effect']
#  Yes, well, I’m the Doppler Effect.
# ['’ m', 'doppler effect']
#  What?
# []
#  What do you suppose he’s doing here? Besides disrupting the local gravity field.
# ['’ s', 'local gravity field']
#  Oh, snap. So I guess we’ll be leaving now.
# ['oh', '’ ll']
#  You have a back-up hypothesis.
# ['back-up hypothesis']
#  Or maybe she wants to be friends, and he wants something more.
# []
#  Yes, but you’re much closer to it than he is.
# ['’ re']
#  And male partners. Animal partners. Large primordial eggplants, pretty much whatever tickled his fancy.
# ['male partners', 'animal', 'large', 'primordial eggplants']
#  True. Why don’t you text him that and see if he backs down?
# ['true', 'don ’ t']
#  Face to face? Are you going to wait for him to sit down, or are you going to stand on a coffee table?
# ['face', 'coffee table']
#  Given the reaction to my costume, this party is a scathing indictment of the American education system.
# ['american education system']
#  Yet another child left behind.
# []
#  Because he is neither tall nor immortal, and none of us could be The Flash.
# ['flash']
#  I’m not. No offence.
# ['’ m']
#  If he understands that, you’re in trouble.
# ['’ re']
#  You’re in trouble.
# ['’ re']
#  Let me remind you, while my moral support is absolute, in a physical confrontation I will be less than useless.
# ['moral support', 'physical confrontation']
#  He’s a Hobbit! I’ve got your back.
# ['’ s', 'hobbit', '’ ve']
#  Happy Halloween. (They leave) If it’s any consolation, I thought that homo-habilus line really put him in his place.
# ['halloween', '’ s', 'homo-habilus line']
#  Tea. When people are upset the cultural convention is to bring them hot beverages. There there. You want to talk about it?
# ['tea', 'cultural convention', 'hot beverages']
#  Good. There there was really all I had.
# []
#  Good night Leonard.
# ['good night', 'leonard']
#  Coming. (Opens door to Howard.)
# ['coming', 'opens', 'howard']
#  He’s not here. Maybe the Avenger summoned him.
# ['’ s', 'avenger']
#  Thank you for the clarification.
# ['thank']
#  Well I’m sure he’ll be fine. He has his hammer.
# ['well', '’ m', '’ ll']
#  If we’re all through playing mock the flawed technology, can we get on with Halo night, we were supposed to start at eight, it is now 8
# ['’ re', 'halo']
#  Yes, first we have to decide if those lost six minutes will be coming out of game time, bathroom time or the pizza break.
# ['game time', 'bathroom time']
#  Oh, what fresh hell is this?
# ['oh', 'fresh hell']
# 8
# []
#  You know, I apologise for my earlier outburst, who needs Halo when we can be regaled with the delightfully folksy tale of the whore of Omaha?
# ['halo', 'folksy tale', 'omaha']
#  Oh good grief.
# ['oh', 'good grief']
#  And I cannot believe people pay for horoscopes, but on a more serious note it’s 8
# ['serious note', '’ s']
#  One on one? We don’t play one on one, we play teams, not one on one. One on one!
# ['don ’ t play']
#  Uh, no. The wheel was a great idea. Relativity was a great idea. This is a notion, and a rather sucky one at that.
# ['uh', 'great idea', 'relativity', 'great idea']
#  Why? Oh, Penny, Penny, Penny.
# ['oh', 'penny', 'penny', 'penny']
#  This is a complex battle simulation with a steep learning curve, there are myriad weapons, vehicles and strategies to master, not to mention an extremely intricate back-story.
# ['complex battle simulation', 'steep learning curve', 'myriad weapons', 'intricate back-story']
#  Mine.
# []
#  Yes, but whoever’s her partner will be hamstrung by her lack of experience and not to mention that fact that sh…. (another explosion)
# ['whoever ’ s']
#  Okay, this isn’t at all good sportsmanship to shoot somebody who’s just respawned, you need to give them a chance to (explosion) now come on!
# ['okay', 'isn ’ t', 'good sportsmanship', '’ s']
#  Raj, Raj, she’s got me cornered, cover me.
# ['raj', 'raj', '’ s']
#  Okay, that’s it, I don’t know how, but she is cheating. No-one can be that attractive and be this skilled at a video game.
# ['okay', '’ s', 'don ’ t', 'no-one', 'video game']
#  What?
# []
#  You laugh now, you just wait until you need tech support.
# ['tech support']
#  And another thing, there’s a certain ethic to the game, Penny, a well estab…
# ['’ s', 'certain ethic', 'penny']
#  Well she could have said goodbye.
# ['well']
#  It’s called carpal tunnel syndrome, and quite frankly you deserve it.
# ['’ s', 'carpal tunnel syndrome']
#  Hold that thought, Leonard, a moment.
# ['hold', 'leonard']
#  Where do I begin?
# []
#  Well first, we don’t have house guests, frankly if I could afford the rent I’d ask you to leave.
# ['well', 'don ’ t', 'house guests', '’ d']
#  Well, our earthquake supplies, we have a two day, two man kit.
# ['well', 'earthquake supplies', 'man kit']
#  So, if there is an earthquake and the three of us are trapped here, we could be out of food by tomorrow afternoon.
# []
#  No-one ever thinks it will happen until it does.
# ['no-one']
#  He’s engaging in reductio-ad-absurdum. It’s the logical fallacy of extending someone’s argument to ridiculous proportions and then criticising the result, and I do not appreciate it.
# ['’ s', '’ s', 'logical fallacy', '’ s argument', 'ridiculous proportions']
#  Okay, well since I’m obviously being ignored here, let’s go over the morning schedule, I use the bathroom from 7 to 7
# ['okay', '’ m', '’ s', 'morning schedule']
#  I suggest no liquids after 11pm.
# []
#  Hmmph, wrong.
# ['hmmph']
#  Your head goes on the other end.
# ['your']
#  It’s culturally universal, a bed, even a temporary bed, is always oriented with the headboard away from the door. It serves the ancient imperative of protecting oneself against marauders.
# ['’ s', 'temporary bed', 'ancient imperative']
#  Hm!
# ['hm']
#  Yes. If you use my toothbrush I’ll jump out that window. Please don’t come to my funeral. Have a good night.
# ['’ ll', 'please', 'don ’ t', 'have', 'good night']
#  Every Saturday since we have lived in this apartment, I have awakened at 6
# []
#  Every Saturday since we have lived in this apartment, I have awakened at 6
# []
#  Because I am neither an invalid nor a woman celebrating Mother’s Day.
# ['mother ’ s day']
#  Okay, this cereal has lost all its molecular integrity, I now have a bowl of shredded wheat paste.
# ['okay', 'molecular integrity', 'wheat paste']
#  Well there’s one beloved children’s book I’ll never read again.
# ['well', '’ s', 'children ’ s book', '’ ll']
#  I’m Sheldon.
# ['’ m', 'sheldon']
#  Oh, terrific, now we’re running a cute little B&B.
# ['oh', '’ re']
#  Well then, it’s all settled, Christie will stay with Howard, Penny can go back to her apartment, and I’ll watch the last 24 minutes of Doctor Who, although at this point it’s more like Doctor Why Bother.
# ['well', '’ s', 'christie', 'howard', 'penny', '’ ll', 'who', '’ s', 'bother']
#  No more talking, everybody go.
# []
#  I imagine there aren’t many kosher corn-huskers.
# ['aren ’ t', 'kosher corn-huskers']
#  I’m sorry, we cannot do this without Wolowitz.
# ['’ m', 'wolowitz']
#  Let me walk you through it, our standard is, the steamed dumpling appetizer, General So’s chicken, beef with broccoli, shrimp with lobster sauce and vegetable lo-main. Do you see the problem?
# ['’ s chicken', 'lobster sauce', 'vegetable lo-main']
#  Our entire order is predicated on four dumplings and four entrees divided among four people.
# ['entire order']
#  Fine, what do you want to eliminate, and who gets the extra dumpling.
# []
#  Then it is no longer a dumpling, once you cut it open it is at best a very small open faced sandwich.
# []
#  He’s putting his needs ahead of the collective good. (Pointing at waiter) Where he comes from, that’s punishable by death.
# ['’ s', 'pointing', '’ s']
#  No, if we fill up on dumplings we’ll need to eliminate another entree.
# ['’ ll need']
#  And divide it how, I’m telling you we cannot do this without Wolowitz.
# ['’ m', 'wolowitz']
#  Have you seen Penny eat Chinese food, she uses a fork, and she double dips her egg rolls.
# ['have', 'penny', 'chinese food', 'double dips', 'egg rolls']
#  Exactly, but we’d have to if she was here.
# ['exactly', '’ d']
#  No.
# []
#  I’ll know.
# ['’ ll']
#  What about the won-tons?
# []
#  It’s Halo night.
# ['’ s', 'halo']
#  Yes. Penny, we would very much appreciate it if you would be the fourth member of our Halo team. I don’t think I need to tell you what an honour this is.
# ['penny', 'halo', 'don ’ t']
#  You can’t go out, it’s Halo night.
# ['’ t', '’ s', 'halo']
#  You go dancing every Wednesday.
# []
#   Then it’s not dancing night.
# ['’ s']
#  Tonight is Halo night, it’s like talking to a wall.
# ['halo', '’ s']
#  Yes, but you didn’t portray her as completely irrational.
# ['didn ’ t portray']
#  Okay, assuming we could dance, which we can’t, there are three of us and two of them.
# ['okay', '’ t']
#  It’s the Chinese restaurant all over again. I assure you that cutting a dumpling in thirds is child’s play compared with three men, each attempting to dance with 67% of a woman.
# ['’ s', 'chinese restaurant', 'child ’ s']
#  Your anger’s not with me, sir, but with basic mathematics.
# ['your', 'anger ’ s', 'basic mathematics']
#  The only man who can restore any semblance of balance to our universe.
# []
#  No, I’m going to ask him to choose between sex and Halo 3. As far as I know, sex has not been upgraded to include high-def graphics and enhanced weapon systems.
# ['’ m', 'halo', 'high-def graphics', 'weapon systems']
#  My point.
# []
#  It’s Halo night.
# ['’ s', 'halo']
#  Shhh!
# ['shhh']
#  I can’t shoot now, I’m cloaking.
# ['’ t shoot', '’ m']
#  That’s why the call it cloaking, dead man.
# ['’ s', 'dead man']
#  We said no tanks.
# []
#  And now you’re out of life. Why did you hit pause?
# ['’ re']
#  Damn you, walletnook.com.
# ['damn']
#  The online description was completely misleading, they said eight slots plus removable ID, to any rational person that would mean room for nine cards, but they don’t tell you the removable ID takes up one slot, it’s a nightmare.
# ['online description', 'id', 'rational person', 'don ’ t', 'id', '’ s']
#  It’s been in every wallet I’ve owned since I was five.
# ['’ s', '’ ve']
#  It says keep this on your person at all times. (Knock on door) It’s right here under Batman’s signature.
# ['knock', '’ s', 'batman', '’ s signature']
#  Hi.
# ['hi']
#  If I may, your parents probably don’t consider this meddling, while arranged marriages are no longer the norm, Indian parents continue to have a greater than average involvement in their children’s lives.
# ['don ’ t', 'indian parents', 'average involvement', 'children ’ s']
#  You seemed confused.
# []
# ...
# ['didn ’ t need']
#  You made me sit on the stairs and think about what I did.
# []
#  What’d you do, delete your photo?
# ['’ d']
#  Fine.
# []
#  Aw, man.
# ['aw']
#  I’d say she’s copying you again, but I’m getting tired of sitting in the hall.
# ['’ d', '’ s', '’ m']
#  Your first date? Did you even measure her walls?
# ['your']
#  Who’s ready to laugh?
# ['who', '’ s']
#  Okay. So, Feynman, Einstein and Schrodinger walk into a bar. Feynman says, it appears
# ['okay', 'feynman', 'einstein', 'schrodinger', 'feynman']
#  That’s a good one. Okay, now, Leonard, you tell a joke.
# ['’ s', 'okay', 'leonard']
#  Comments from our Behind the Flags retrospective. Get this, people are calling it the longest one yet.
# ['comments', 'flags']
#  He’s not wrong. It was your crackpot idea that he deserves love.
# ['’ s', 'crackpot idea']
#  You and Leonard don’t have anything in common. Maybe you should break up.
# ['leonard', 'don ’ t']
#  Actually, our friendship group is at capacity. But if anybody drops out, you’re at the top of the list. Unless it’s Raj, in which case, we’ll probably get a person of colour.
# ['friendship group', '’ re', 'unless', '’ s', 'raj', '’ ll']
#  So he’s using his money to attract a mate. Is that any different than me using my intelligence to attract Amy? Or Leonard using his power of grovelling to get Penny?
# ['’ s', 'amy', 'leonard', 'penny']
#  Oh, so many things. Her mind, her kindness, and especially her body.
# ['oh']
#  Hello. I’m Dr. Sheldon Cooper.
# ['hello', '’ m dr.', 'sheldon cooper']
#  Based on the glowing reception of our recent Behind the Flags retrospective, we thought you might like to see how it all came together.
# ['based', 'flags']
#  Ooh, we already have our first call.
# ['ooh']
#  Okay, one second.
# ['okay']
#  I’m trying to shoot.
# ['’ m']
#  What happened to me? I used to excel at these things.
# []
#  Well, I don’t like it.
# ['well', 'don ’ t']
#  No, but it’s not just video games. I downloaded the new O.S. for my phone, took me a week to stop accidentally texting kissy faces to everyone.
# ['’ s', 'video games', 'o.s']
#  I guess I just need to face it, I’m no longer a wunderkind. Now I just wonder what’s for lunch.
# ['’ m', '’ s']
#  Yay.
# ['yay']
#  I’ve been thinking about our recent humiliation.
# ['’ ve', 'recent humiliation']
#  At the hands of those teenagers.
# []
#  Boy teenagers.
# []
#  I started doing some reading on cognitive vitality, and I came across an area of research called super-aging.
# ['cognitive vitality']
#  The theory is that if you really tax your brain, the neurofibers will become thicker and the glial cells more lustrous.
# ['glial cells']
#  Well, it’s not just doing simple cognitive tasks. You need to push your brain out of its comfort zone and reach mental exhaustion.
# ['well', '’ s', 'simple cognitive tasks', 'comfort zone', 'mental exhaustion']
#  Jab mein aat saal ka tha maine seekha tha. (I did that when I was eight)
# ['jab', 'mein aat saal ka tha maine seekha tha']
#  Hey.
# ['hey']
#  Raj is teaching me to make croissants.
# ['raj']
#  Yes. Yeah, it seemed daunting at first, but then I realized, it’s like the chemistry set I had as a kid. Only, when your brother eats this, no one has to call Poison Control.
# ['yeah', '’ s', 'brother eats', 'poison']
#  Yes, it is delicious. Physicist, baker, lover, what can’t I do?
# ['physicist', '’ t']
#  For the last time, I am not having a tickle fight with you.
# ['tickle fight']
#  You’re just using food to mask the fear that you’re fundamentally unlovable and therefore going to be alone forever.
# ['’ re', '’ re']
#  It really doesn’t matter, as long as it’s challenging.
# ['doesn ’ t matter', '’ s']
#  Howard, I’m trying to make myself uncomfortable, not everyone else.
# ['howard', '’ m']
#  Okay, I think I got that.
# ['okay']
#  Okay. Just to be on the safe side, am I in any danger of getting juggler’s elbow?
# ['okay', 'safe side', 'juggler ’ s elbow']
#  Are you sure? ‘Cause I’m feeling a twinge.
# ['cause', '’ m feeling']
#  Amy, look, I’m on a unicycle!
# ['amy', '’ m']
#  I hurt myself juggling.
# []
#  Howard said I could borrow it, Bernadette said forever.
# ['howard', 'bernadette']
#  What, are you crazy? I’m on a unicycle.
# ['’ m']
#  Wait, I need help getting down.
# ['wait']
#  Drag out our mattress and put it over here, then go across the hall, get their mattress and put it over here. But before you do any of that, scratch my nose.
# ['drag']
#  I’m returning this stuff to Howard.
# ['’ m', 'howard']
#  Oh, I stopped that, it was dumb. Uni, bi, tri, menstrual, all cycles are dumb.
# ['oh', 'uni']
#  Well, it is. If I wanted to hold three things at once, I’d wear cargo pants.
# ['well', '’ d', 'cargo pants']
#  Are you calling me a quitter?
# []
#  This conversation is over.
# []
#  Thank you.
# ['thank']
#  It’s okay, I stopped being upset about that. And no, the irony is not lost on me.
# ['’ s okay']
#  This article says the peak age for making a Nobel Prize-winning discovery is 40.
# ['peak age', 'nobel prize-winning']
#  So I’m running out of time.
# ['’ m']
#  Oh, you have to say that, you’re sweet on me.
# ['oh', '’ re sweet']
#  Hey, I thought you were sweet on me.
# ['hey']
#  You’re so cute. I’m gonna go learn how to walk on stilts.
# ['’ re', '’ m gon na']
#  I’m doing it. I’m doing it. I’m tall and I’m doing it. (Waking up in bed) Ah, man.
# ['’ m', '’ m', '’ m', '’ m', 'waking']
#  Thank you. No bendy straw, some party.
# ['thank', 'bendy straw']
#  To success without Raj.
# ['raj']
#  Yeah, I’ll definitely live long enough. Vitamin C.
# ['yeah', '’ ll', 'vitamin']
#  I hope his character doesn’t make it into the movie, he’s kind of a bummer.
# ['character doesn ’ t', '’ s kind']
#  Who else has access to this room?
# ['who']
#  This is disconcerting.
# []
#  Where did you move it?
# []
#  Wait, so you’re just going to take all the work we’ve done for the last year and toss us aside?
# ['wait', '’ re', '’ ve']
#  If that’s sarcasm, please save it for our enemies.
# ['’ s sarcasm']
#  You know, I have a good mind to stop paying my taxes. It’s too bad I enjoy doing them so much. The Air Force did it again. They’re erasing our lives.
# ['good mind', '’ s', 'air force', '’ re']
#  It’s okay, everything’s here.
# ['’ s okay', '’ s']
#  I feel so betrayed. You know, all my life I thought Uncle Sam was a friendly uncle who brought you presents. Turns out he’s the other kind.
# ['uncle sam', 'friendly uncle', 'turns', '’ s']
#  Thank you. Can we just talk about something else?
# ['thank']
#  I apologize for exceeding my allotted bathroom time.
# ['bathroom time']
#  Not really. Apparently grief can make one less regular.
# []
#  No, I sat and I sat, but to no avail.
# []
#  What’s the occasion?
# ['’ s']
#  You’re so kind. You know, I don’t know how I ever got by without you.
# ['’ re', 'don ’ t']
#  Well, I thought that, too, but I’ve come to realize, I am completely dependent on you.
# ['well', '’ ve']
#  No, to wake up every morning and know you’re there is a great comfort to me. Mmm, tasteless. How do you do it?
# ['’ re', 'great comfort', 'mmm']
#  Well, there is our quantum cognition experiment. You and I could spend more time on that.
# ['well', 'quantum cognition experiment']
#  I’m confused. You’re always saying that you want to spend more time with me.
# ['’ m', '’ re']
#  Well, a lot, it’s very annoying. Has something changed? Um, is there something that you’re not telling me?
# ['well', '’ s', 'um', '’ re']
#  Princeton? A fine institution. The place where Albert Einstein taught. And where Leonard got his PhD, so it may have gone downhill.
# ['princeton', 'fine institution', 'albert einstein', 'leonard', 'phd']
#  Well, that’s wonderful. Congratulations.
# ['well', '’ s', 'congratulations']
#  What is there to talk about? You have to take it. It’s important.
# ['’ s']
#  Thank you, but I’ll be fine.
# ['thank', '’ ll']
#  Yes. I may have lost my guidance system and my girlfriend, but I still have a colon full of yesterday’s meals to keep me company. Although, thanks to your high fibre breakfast, I’m sure that’ll be leaving me, too.
# ['guidance system', '’ s meals', 'high fibre breakfast', '’ m', '’ ll']
#  What does it look like? I’m playing sad harmonica in an apartment as empty as my heart.
# ['’ m', 'sad harmonica']
#  I got the blues. My baby done left me.
# []
#  Am I? Yesterday I had an Air Force project, a girlfriend who lived with me, and my good friend Raj right across the hall.
# ['am', 'yesterday', 'air force project', 'good friend', 'raj']
#  No, but that list was sounding a little thin.
# []
#  So trick her.
# []
#  No, but you are, so I got you this as a present.
# []
#  No, it is. Leonard pointed out to me that I’m not always a loving and supportive boyfriend, so here’s some quality luggage.
# ['leonard', '’ m', 'supportive boyfriend', '’ s', 'quality luggage']
#  The salesman said it could survive a plane crash, so perhaps you should fly inside it.
# ['plane crash']
#  Well, I’m not looking forward to it, but it is a wonderful opportunity and you need to take it. Besides, Princeton is in New Jersey, so it’s not like you’re gonna want to stay. Uh, I know it’s not your birthday, but if you’re interested…
# ['well', '’ m', 'wonderful opportunity', 'princeton', 'jersey', '’ s', '’ re gon na', 'uh', '’ s', '’ re interested…']
#  Okay. Oh, and just to be clear, I’m not being intimate with you in order to keep you from going.
# ['okay', 'oh', '’ m']
#  Well, no, it’s just, I’m just warning you, you know, if you find yourself 3,000 miles away and craving a hit of this, you know, I can’t Skype it to you.
# ['well', '’ s', '’ m', '’ t', 'skype']
#  All right, then. Let’s go to the bedroom, remove our clothes, fold them neatly and engage in frenzied lovemaking.
# ['’ s']
#  Or, what if we fold them?
# []
#  Of course. Here, here, let me. I’ve been doing a little research on New Jersey, and I was delighted to learn that their chief agricultural product is sod.
# ['’ ve', 'jersey', 'chief agricultural product']
#  Hmm, yes. Yeah, perhaps I’ve been harder on them than they deserve.
# ['hmm', 'yeah', '’ ve']
#  It’s hard to say. I’ve never really lived by myself. What if I become strange and eccentric?
# ['’ s', '’ ve']
#  Howard Hughes saved his urine in milk bottles.
# ['howard hughes', 'milk bottles']
#  And you’ll text me when you arrive at the airport?
# ['’ ll text']
#  And when you’re at the gate?
# ['’ re']
#  And if you see any actors from Game of Thrones in first class?
# ['game', 'thrones']
#  And don’t forget to Skype me when you arrive.
# ['don ’ t', 'skype']
#  And every morning.
# []
#  Now of course, my 9am is your noon, so let’s avoid the whole good morning, good afternoon minefield, and let’s just say hello.
# ['’ s', 'whole good morning', 'good afternoon minefield', '’ s']
#  And just remember, I am proud of you and I support you in all that you do.
# []
#  Oh, and one last thing. If you find yourself working with a male scientist who’s as smart as me, as tall as me and has hair like Thor, well, then I want you to step away from the situation and call me immediately.
# ['oh', 'male scientist', '’ s', 'thor']
#  How are you settling in?
# []
#  Now, I’ve learned some fun facts about New Jersey to help you make small talk. Would you like to know the state bird or the murder rate? They’re both shocking.
# ['’ ve', 'fun facts', 'jersey', 'small talk', 'state bird', 'murder rate', '’ re']
#  Well, I’m a lot less likely to see an Eastern Goldfinch or be murdered, I’ll tell you that.
# ['well', '’ m', 'goldfinch', '’ ll']
#  I miss you, too.
# []
#  I’m sorry you had to go through that.
# ['’ m']
#  You know you just split an infinitive.
# []
#  I am. It is naughty to put an adverb between the word to and the verb stem.
# ['verb stem']
#  I’m going to admonish you.
# ['’ m']
#  That’s the only kind of admonishing I do.
# ['’ s']
#  Gentlemen. You may remember Dr. Nowitzki, She’s back at Caltech for her postdoc.
# ['gentlemen', 'nowitzki', '’ s', 'caltech']
#  Oh, thanks. Dr. Nowitzki’s going to tell me about the work she did at CERN. And she brought me this duty-free Toblerone.
# ['oh', 'nowitzki', '’ s', 'cern', 'toblerone']
#  Let’s sit somewhere else.
# ['’ s']
#  So, tell me about your scalar dark energy experiment.
# ['dark energy experiment']
#  Oh. You must be one of those dessert before dinner people.
# ['oh', 'dinner people']
#  And get this, I saw an articulating ladder with dual-leg leveling, which delivers stability and adaptability to uneven terrain.
# ['delivers stability', 'uneven terrain']
#  Yeah. Raj made the funniest joke, he said, which is the best ladder to use to hang myself?
# ['yeah', 'raj', 'funniest joke']
#  Oh, not at all. I’ve had outings with Leonard and Raj in the evening, and, oh, I had lunch
# ['oh', '’ ve', 'leonard', 'raj']
#  Oh, Dr. Nowitzki is a woman.
# ['oh', 'nowitzki']
#  Many years ago. Back when she was a grad student. She’s always been a huge fan of my work, and now she’s doing research at Caltech.
# ['grad student', '’ s', 'huge fan', '’ s', 'caltech']
#  Yes. I think you’d like her. She’s extremely intelligent, just like you. Unlike you, she’s tall, blonde and used to be an Olympic swimmer.
# ['’ d', '’ s', '’ s', 'olympic swimmer']
#  Hey, everybody. This is my friend, Dr. Nowitzki.
# ['hey', 'nowitzki']
#  We just went swimming.
# []
#  I was scared, but I told myself it’s just a big bathtub. Then I got scared again ’cause there are all these strangers in my bathtub.
# ['’ s', 'big bathtub']
#  Well, I was hiding from a bee, but it still counts.
# ['well']
#  Yes, we skyped this morning and I’m sure I’ll check in with her before I go to sleep.
# ['’ m', '’ ll check']
#  That is true. She keeps asking how long Amy’s going to be gone.
# ['amy', '’ s']
#  Leonard, your wife is sitting right here. What are you doing?
# ['leonard']
#  She was part of the American team at CERN.
# ['american team', 'cern']
#  Do you know, I’ve corresponded with Peter Higgs. Would you like to see some of his letters?
# ['’ ve', 'peter higgs']
#  I’ll get them.
# ['’ ll']
#  Oh, fun. Like a play date.
# ['oh']
#  Here you go.
# []
#  Hmm? Oh, no, no, no. They’re from many famous people. See? Oh, like this one. This is from Patrick Stewart. It says if I come to his house again, I get to meet his dogs. Oh, excuse me.
# ['hmm', 'oh', '’ re', 'famous people', 'oh', 'patrick stewart', 'oh']
#  Oh, hello, Amy.
# ['oh', 'amy']
#  I miss you, too. Hey, this is good timing. Remember that Dr. Nowitzki I told you about? She’s right here.
# ['hey', 'good timing', 'remember', 'nowitzki', '’ s']
#  What is Leonard doing calling you at this hour?
# ['leonard']
#  I must tell you, that seems a little inappropriate. Don’t you agree?
# ['don', '’ t']
#  See? We both think so.
# []
#  Hey, I hate to break up the party, but Amy says I’m tired and have to go to bed.
# ['hey', 'amy', '’ m']
#  Of course.
# []
#  That was fun. It was like Mario Kart.
# ['mario kart']
#  Bye.
# ['bye']
#  What? Is this about Leonard and Amy? I don’t like it either.
# ['leonard', 'amy', 'don ’ t']
#  That doesn’t make any sense. She knows I have a girlfriend.
# ['doesn ’ t']
#  That may be true, but Dr. Nowitzki’s just a friend. In fact, I wouldn’t have even noticed she’s a woman if she hadn’t worn that bathing suit that highlighted her bosom.
# ['nowitzki', '’ s', 'wouldn ’ t', '’ s', 'hadn ’ t']
#  I already do.
# []
#  Because there’s only one of me, I’m more valuable.
# ['’ s', '’ m']
#  Although, Amy’s already taken me out of my package and played with me.
# ['amy', '’ s']
#  Penny, look. I appreciate your concern, but I don’t think that’s what’s happening.
# ['penny', 'don ’ t', '’ s', '’ s']
#  I think Dr. Nowitzki is a friendly colleague. I think you and Leonard need to see a marriage counsellor. And I need to update my résumé to include swimming as a special skill.
# ['nowitzki', 'friendly colleague', 'leonard', 'marriage counsellor', 'special skill']
#  Uh, breakfast yes, lunch no. I did have a cough drop, but that really rides the line between sucking and eating.
# ['uh', 'breakfast yes', 'cough drop']
#  How thoughtful. Thank you.
# ['thank']
#  And I with you. Question, are you seeking a romantic relationship with me?
# ['romantic relationship']
#  Well, that would raise a number of problems. We’re colleagues. I’m currently in a relation… Excuse me a moment.
# ['well', '’ re colleagues', '’ m', 'excuse']
#  (Knock, knock, knock) Amy. (Knock, knock, knock) Amy. (Knock, knock, knock) Amy. Will you marry me?
# ['knock', 'amy', 'knock', 'amy', 'knock', 'amy', 'will']

# %%
import nltk
nltk.download('brown')
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Aditya\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\brown.zip.
# True
